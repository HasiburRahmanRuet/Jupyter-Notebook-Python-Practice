# %%
import pandas as pd

# %%
ufo=pd.read_csv('ufo.csv')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['Location']=ufo.City+','+ufo.State
ufo.Location
# Out:
# 0                      Ithaca,NY
# 1                 Willingboro,NJ
# 2                     Holyoke,CO
# 3                     Abilene,KS
# 4        New York Worlds Fair,NY
#                   ...
# 18236              Grant Park,IL
# 18237             Spirit Lake,IA
# 18238             Eagle River,WI
# 18239             Eagle River,WI
# 18240                    Ybor,FL
# Name: Location, Length: 18241, dtype: object

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                   Location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
movies=pd.read_csv("imdb_1000.csv")

# %%
movies.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
movies.describe(include='object')
# Out:
#                  title content_rating  genre  \
# count              979            976    979
# unique             975             12     16
# top     Les Miserables              R  Drama
# freq                 2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
 ufo.columns=ufo.columns.str.replace(" ","_")

# %%
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
ufo.State.sort_values(ascending=False)
# Out:
# 12079    WY
# 11490    WY
# 11333    WY
# 4866     WY
# 3326     WY
#          ..
# 2929     AK
# 103      AK
# 3511     AK
# 14421    AK
# 10454    AK
# Name: State, Length: 18241, dtype: object

# %%
ufo.sort_values('State')
# Out:
#                             City Colors_Reported Shape_Reported State  \
# 10454                  Anchorage             NaN       CYLINDER    AK
# 14421                     Seward             NaN          LIGHT    AK
# 3511               Kodiak Island             NaN         CIRCLE    AK
# 103                    Anchorage             NaN           DISK    AK
# 2929                      Nulato             NaN          LIGHT    AK
# ...                          ...             ...            ...   ...
# 3326                      Casper             NaN         CIRCLE    WY
# 4866                     Wyoming             NaN          OTHER    WY
# 11333                  Ten Sleep             NaN           DISK    WY
# 11490                   Cheyenne             NaN            NaN    WY
# 12079  Medicine Bow Natl. Forest             NaN       TRIANGLE    WY
#
#                   Time                      Location
# 10454  6/30/1997 12:00                  Anchorage,AK
# ...

# %%
ufo.sort_values(['Location','Time'])
# Out:
#             City Colors_Reported Shape_Reported State              Time  \
# 1761   Abbeville             NaN           DISK    SC   12/10/1968 0:30
# 9404    Aberdeen             NaN           DISK    MD   6/15/1996 13:30
# 2297    Aberdeen             NaN       TRIANGLE    MD    8/18/1972 1:30
# 16167   Aberdeen             NaN        VARIOUS    OH    3/29/2000 3:00
# 389     Aberdeen          ORANGE         CIRCLE    SD  11/15/1956 18:30
# ...          ...             ...            ...   ...               ...
# 2013         NaN             NaN            NaN    NH     8/1/1970 9:30
# 21           NaN             NaN            NaN    LA    8/15/1943 0:00
# 22           NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 1877         NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 9587         NaN             NaN            EGG    FL   8/24/1996 15:00
#
#            Location
# 1761   Abbeville,SC
# 9404    Aberdeen,MD
# 2297    Aberdeen,MD
# ...

# %%
movies.shape
# Out:
# (979, 6)

# %%
boolean=[]
for length in movies.duration:
    if length>=200:
        boolean.append(True)
    else:
        boolean.append(False)

# %%
boolean[0:10]
# Out:
# [False, False, True, False, False, False, False, True, False, False]

# %%
movies[pd.Series(boolean)]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
is_long=movies.duration>=200
is_long
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: duration, Length: 979, dtype: bool

# %%
movies[movies.duration<200]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 3            PG-13     Action       152
# ...

# %%
movies[(movies.duration >= 200) & (movies.genre =='Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
True & False
# Out:
# False

# %%
movies[(movies.star_rating>8.9) & (movies.duration<=200)]
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
ufo.head(4)
# Out:
#           City Colors_Reported Shape_Reported State             Time  \
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3      Abilene             NaN           DISK    KS   6/1/1931 13:00
#
#          Location
# 0       Ithaca,NY
# 1  Willingboro,NJ
# 2      Holyoke,CO
# 3      Abilene,KS

# %%
for index,row in ufo.iterrows():
   print(index,row.City,row.State,row.Shape_Reported)
# Out:
# 0 Ithaca NY TRIANGLE
# 1 Willingboro NJ OTHER
# 2 Holyoke CO OVAL
# 3 Abilene KS DISK
# 4 New York Worlds Fair NY LIGHT
# 5 Valley City ND DISK
# 6 Crater Lake CA CIRCLE
# 7 Alma MI DISK
# 8 Eklutna AK CIGAR
# 9 Hubbard OR CYLINDER
# 10 Fontana CA LIGHT
# 11 Waterloo AL FIREBALL
# 12 Belton SC SPHERE
# 13 Keokuk IA OVAL
# 14 Ludington MI DISK
# 15 Forest Home CA CIRCLE
# 16 Los Angeles CA nan
# 17 Hapeville GA nan
# 18 Oneida TN RECTANGLE
# 19 Bering Sea AK OTHER
# 20 Nebraska NE DISK
# 21 nan LA nan
# 22 nan LA LIGHT
# 23 Owensboro KY RECTANGLE
# 24 Wilderness WV DISK
# 25 San Diego CA CIGAR
# 26 Wilderness WV DISK
# 27 Clovis NM DISK
# 28 Los Alamos NM DISK
# 29 Ft. Duschene UT DISK
# 30 South Kingstown RI SPHERE
# 31 North Tampa FL CYLINDER
# 32 Ft. Lee VA CIGAR
# 33 Salinas AFB CA DISK
# 34 Jasper FL FIREBALL
# 35 Winston-Salem NC DISK
# 36 Portsmouth VA FORMATION
# 37 Dallas TX SPHERE
# 38 Huntington Beach CA DISK
# 39 San Antonio NM OVAL
# 40 Roswell NM SPHERE
# ...

# %%
drinks=pd.read_csv("drinks.csv",dtype={'beer_servings': float})
drinks.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.mean(axis=1).head()
# Out:
# 0      0.000
# 1     69.975
# 2      9.925
# 3    176.850
# 4     81.225
# dtype: float64

# %%
chipotle=pd.read_table("chipotle.tsv")
chipotle.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipotle[chipotle.item_name.str.contains('Chicken')].item_name
# Out:
# 4               Chicken Bowl
# 5               Chicken Bowl
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
# 13              Chicken Bowl
#                 ...
# 4604            Chicken Bowl
# 4615      Chicken Soft Tacos
# 4619      Chicken Salad Bowl
# 4620      Chicken Salad Bowl
# 4621      Chicken Salad Bowl
# Name: item_name, Length: 1560, dtype: object

# %%
chipotle.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipotle.choice_description=chipotle.choice_description.str.replace('[','').str.replace(']','')

# %%
chipotle.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                         Clementine     $3.39
# 2                                              Apple     $3.39
# 3                                                NaN     $2.39
# 4  Tomatillo-Red Chili Salsa (Hot), Black Beans, ...    $16.98

# %%
drinks.groupby('continent').mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
drinks.groupby('continent').mean().plot(kind='bar')

# %%
movies[(movies.star_rating>8)&(movies.genre=='Comedy')]
# Out:
#      star_rating                                              title  \
# 25           8.6                                  Life Is Beautiful
# 29           8.6                                        City Lights
# 35           8.6                                       Modern Times
# 48           8.5  Dr. Strangelove or: How I Learned to Stop Worr...
# 52           8.5                                 The Great Dictator
# 60           8.5                                           3 Idiots
# 66           8.4                                Munna Bhai M.B.B.S.
# 70           8.4                                             Amelie
# 88           8.4                                            The Kid
# 93           8.4                        Dilwale Dulhania Le Jayenge
# 94           8.4                                Singin' in the Rain
# 97           8.4                                          The Sting
# 103          8.3                                      The Apartment
# ...

# %%
movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies.genre.nunique()
# Out:
# 16

# %%
movies.duration.plot(kind='bar')

# %%
movies.plot(kind='box')

# %%
ufo.isnull()
# Out:
#         City  Colors_Reported  Shape_Reported  State   Time  Location
# 0      False             True           False  False  False     False
# 1      False             True           False  False  False     False
# 2      False             True           False  False  False     False
# 3      False             True           False  False  False     False
# 4      False             True           False  False  False     False
# ...      ...              ...             ...    ...    ...       ...
# 18236  False             True           False  False  False     False
# 18237  False             True           False  False  False     False
# 18238  False             True            True  False  False     False
# 18239  False            False           False  False  False     False
# 18240  False             True           False  False  False     False
#
# [18241 rows x 6 columns]

# %%
ufo.isnull().sum()
ufo.isnull().shape
# Out:
# (18241, 6)

# %%
ufo.dropna(subset=['City','Shape_Reported'],how='all').shape
# Out:
# (18237, 6)
